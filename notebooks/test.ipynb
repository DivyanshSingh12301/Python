# %%
import pandas as pd

# Creating a simple dataset
data = {
    'Roll No': [1, 2, 3],
    'Name': ['Arjun', 'Bhavana', 'Charlie'],
    'Branch': ['ICE', 'ICE', 'ECE']
}

df = pd.DataFrame(data)
df
# Out:
#    Roll No     Name Branch
# 0        1    Arjun    ICE
# 1        2  Bhavana    ICE
# 2        3  Charlie    ECE
